# %% [markdown]
# # ライブラリインポート

# %%
import random

import numpy as np
from numpy.typing import NDArray

# %% [markdown]
# # 条件設定

# %%
# 都市間の距離行列(隣接行列)
# distances[i][j]は都市iからjまでの距離
distances: NDArray[np.int_] = np.array([
    [0, 2, 9, 10], # 都市0(この行)から都市1へは距離2、都市2へは距離9、都市3へは距離10です
    [1, 0, 6, 4],
    [15, 7, 0, 8],
    [6, 3, 12, 0]
])

# %% [markdown]
# # 関数

# %% [markdown]
# ## 個体の表現
# 各個体は都市の訪問順序を表す。

# %%
def generate_individual(num_cities: int) -> list[int]:
    """ 都市の訪問順序をランダムに生成する """
    route = list(range(num_cities))
    random.shuffle(route)
    return route

# %% [markdown]
# ## 適応度関数
# 訪問ルートの総距離の逆数とする。小さいほど適応度が高いことになる。

# %%
def fitness(route: list[int], distance_matrix: NDArray[np.int_]) -> float:
    """ ルートの総距離を計算し、適応度を返す """
    total_distance = 0
    for i in range(len(route)):
        total_distance += distance_matrix[route[i-1]][route[i]]
    return 1 / total_distance

# %% [markdown]
# # 選択

# %%
def tournament_selection(population: list[list[int]], scores: list[float], k: int=3):
    """ トーナメント選択を行う関数 """
    # トーナメントのサイズkでランダムに個体を選ぶ
    selection: list[tuple[list[int], float]] = random.sample(list(zip(population, scores)), k) # (polulation, score)のペアをランダムにk個取り出す
    # 適応度が最も高い個体を選ぶ
    selected = max(selection, key=lambda x: x[1])
    return selected[0]

# %% [markdown]
# ## 交叉
# 順番を保持する必要がある。

# %%
def crossover(parent1: list[int], parent2: list[int]):
    """ 一様順序交叉を行う """
    child = [-1] * len(parent1)
    indices = sorted(random.sample(range(len(parent1)), 2))
    child[indices[0]:indices[1]] = parent1[indices[0]:indices[1]]
    
    fill_from = indices[1]
    for gene in parent2:
        if gene not in child:
            if fill_from >= len(parent1):
                fill_from = 0
            child[fill_from] = gene
            fill_from += 1
            
    return child

# %% [markdown]
# ## 突然変異

# %%
def mutate(route: list[int], mutation_rate: float=0.02):
    """ 2-opt法による突然変異 """
    if random.random() < mutation_rate:
        i, j = sorted(random.sample(range(len(route)), 2))
        route[i:j+1] = reversed(route[i:j+1])
    return route

# %% [markdown]
# # メインループ

# %%
def genetic_algorithm(distance_matrix, population_size=100, generations=200, mutation_rate=0.02):
    """ 遺伝的アルゴリズムのメイン関数 """
    num_cities = len(distance_matrix)
    population = [generate_individual(num_cities) for _ in range(population_size)]
    best_route = None
    best_fitness = float('inf')

    for generation in range(generations):
        # 適応度を計算
        fitnesses = [fitness(individual, distance_matrix) for individual in population]
        
        # 次世代の個体群を選択
        new_population = []
        for _ in range(population_size):
            parent1 = tournament_selection(population, fitnesses)
            parent2 = tournament_selection(population, fitnesses)
            child = crossover(parent1, parent2)
            new_population.append(mutate(child, mutation_rate))
        
        population = new_population
        
        # 最良の解を更新
        current_best_fitness = min(fitnesses)
        if current_best_fitness < best_fitness:
            best_fitness = current_best_fitness
            best_route = population[fitnesses.index(current_best_fitness)]
        
        # 進捗を表示
        print(f"Generation {generation}: Best Fitness = {1 / best_fitness}")

    return best_route, 1 / best_fitness

# %%
distance_matrix = np.array([
    [0, 2, 9, 10],
    [1, 0, 6, 4],
    [15, 7, 0, 8],
    [6, 3, 12, 0]
])
best_route, best_distance = genetic_algorithm(distance_matrix)
print("Best Route:", best_route)
print("Best Distance:", best_distance)
# Out:
# Generation 0: Best Fitness = 34.0
# Generation 1: Best Fitness = 34.0
# Generation 2: Best Fitness = 34.0
# Generation 3: Best Fitness = 34.0
# Generation 4: Best Fitness = 34.0
# Generation 5: Best Fitness = 34.0
# Generation 6: Best Fitness = 34.0
# Generation 7: Best Fitness = 34.0
# Generation 8: Best Fitness = 34.0
# Generation 9: Best Fitness = 34.0
# Generation 10: Best Fitness = 34.0
# Generation 11: Best Fitness = 34.0
# Generation 12: Best Fitness = 34.0
# Generation 13: Best Fitness = 34.0
# Generation 14: Best Fitness = 34.0
# Generation 15: Best Fitness = 34.0
# Generation 16: Best Fitness = 34.0
# Generation 17: Best Fitness = 34.0
# Generation 18: Best Fitness = 34.0
# Generation 19: Best Fitness = 34.0
# Generation 20: Best Fitness = 34.0
# Generation 21: Best Fitness = 34.0
# Generation 22: Best Fitness = 34.0
# Generation 23: Best Fitness = 34.0
# Generation 24: Best Fitness = 34.0
# Generation 25: Best Fitness = 34.0
# Generation 26: Best Fitness = 34.0
# Generation 27: Best Fitness = 34.0
# Generation 28: Best Fitness = 34.0
# Generation 29: Best Fitness = 34.0
# Generation 30: Best Fitness = 34.0
# Generation 31: Best Fitness = 34.0
# Generation 32: Best Fitness = 34.0
# Generation 33: Best Fitness = 34.0
# Generation 34: Best Fitness = 34.0
# Generation 35: Best Fitness = 34.0
# Generation 36: Best Fitness = 34.0
# Generation 37: Best Fitness = 34.0
# Generation 38: Best Fitness = 34.0
# Generation 39: Best Fitness = 34.0
# Generation 40: Best Fitness = 34.0
# Generation 41: Best Fitness = 34.0
# Generation 42: Best Fitness = 34.0
# Generation 43: Best Fitness = 34.0
# Generation 44: Best Fitness = 34.0
# Generation 45: Best Fitness = 34.0
# Generation 46: Best Fitness = 34.0
# Generation 47: Best Fitness = 34.0
# Generation 48: Best Fitness = 34.0
# Generation 49: Best Fitness = 34.0
# Generation 50: Best Fitness = 34.0
# Generation 51: Best Fitness = 34.0
# Generation 52: Best Fitness = 34.0
# Generation 53: Best Fitness = 34.0
# Generation 54: Best Fitness = 34.0
# Generation 55: Best Fitness = 34.0
# Generation 56: Best Fitness = 34.0
# Generation 57: Best Fitness = 34.0
# Generation 58: Best Fitness = 34.0
# Generation 59: Best Fitness = 34.0
# Generation 60: Best Fitness = 34.0
# Generation 61: Best Fitness = 34.0
# Generation 62: Best Fitness = 34.0
# Generation 63: Best Fitness = 34.0
# Generation 64: Best Fitness = 34.0
# Generation 65: Best Fitness = 34.0
# Generation 66: Best Fitness = 34.0
# Generation 67: Best Fitness = 34.0
# Generation 68: Best Fitness = 34.0
# Generation 69: Best Fitness = 34.0
# Generation 70: Best Fitness = 34.0
# Generation 71: Best Fitness = 34.0
# Generation 72: Best Fitness = 34.0
# Generation 73: Best Fitness = 34.0
# Generation 74: Best Fitness = 34.0
# Generation 75: Best Fitness = 34.0
# Generation 76: Best Fitness = 34.0
# Generation 77: Best Fitness = 34.0
# Generation 78: Best Fitness = 34.0
# Generation 79: Best Fitness = 34.0
# Generation 80: Best Fitness = 34.0
# Generation 81: Best Fitness = 34.0
# Generation 82: Best Fitness = 34.0
# Generation 83: Best Fitness = 34.0
# Generation 84: Best Fitness = 34.0
# Generation 85: Best Fitness = 34.0
# Generation 86: Best Fitness = 34.0
# Generation 87: Best Fitness = 34.0
# Generation 88: Best Fitness = 34.0
# Generation 89: Best Fitness = 34.0
# Generation 90: Best Fitness = 34.0
# Generation 91: Best Fitness = 34.0
# Generation 92: Best Fitness = 34.0
# Generation 93: Best Fitness = 34.0
# Generation 94: Best Fitness = 34.0
# Generation 95: Best Fitness = 34.0
# Generation 96: Best Fitness = 34.0
# Generation 97: Best Fitness = 34.0
# Generation 98: Best Fitness = 34.0
# Generation 99: Best Fitness = 34.0
# Generation 100: Best Fitness = 34.0
# Generation 101: Best Fitness = 34.0
# Generation 102: Best Fitness = 34.0
# Generation 103: Best Fitness = 34.0
# Generation 104: Best Fitness = 34.0
# Generation 105: Best Fitness = 34.0
# Generation 106: Best Fitness = 34.0
# Generation 107: Best Fitness = 34.0
# Generation 108: Best Fitness = 34.0
# Generation 109: Best Fitness = 34.0
# Generation 110: Best Fitness = 34.0
# Generation 111: Best Fitness = 34.0
# Generation 112: Best Fitness = 34.0
# Generation 113: Best Fitness = 34.0
# Generation 114: Best Fitness = 34.0
# Generation 115: Best Fitness = 34.0
# Generation 116: Best Fitness = 34.0
# Generation 117: Best Fitness = 34.0
# Generation 118: Best Fitness = 34.0
# Generation 119: Best Fitness = 34.0
# Generation 120: Best Fitness = 34.0
# Generation 121: Best Fitness = 34.0
# Generation 122: Best Fitness = 34.0
# Generation 123: Best Fitness = 34.0
# Generation 124: Best Fitness = 34.0
# Generation 125: Best Fitness = 34.0
# Generation 126: Best Fitness = 34.0
# Generation 127: Best Fitness = 34.0
# Generation 128: Best Fitness = 34.0
# Generation 129: Best Fitness = 34.0
# Generation 130: Best Fitness = 34.0
# Generation 131: Best Fitness = 34.0
# Generation 132: Best Fitness = 34.0
# Generation 133: Best Fitness = 34.0
# Generation 134: Best Fitness = 34.0
# Generation 135: Best Fitness = 34.0
# Generation 136: Best Fitness = 34.0
# Generation 137: Best Fitness = 34.0
# Generation 138: Best Fitness = 34.0
# Generation 139: Best Fitness = 34.0
# Generation 140: Best Fitness = 34.0
# Generation 141: Best Fitness = 34.0
# Generation 142: Best Fitness = 34.0
# Generation 143: Best Fitness = 34.0
# Generation 144: Best Fitness = 34.0
# Generation 145: Best Fitness = 34.0
# Generation 146: Best Fitness = 34.0
# Generation 147: Best Fitness = 34.0
# Generation 148: Best Fitness = 34.0
# Generation 149: Best Fitness = 34.0
# Generation 150: Best Fitness = 34.0
# Generation 151: Best Fitness = 34.0
# Generation 152: Best Fitness = 34.0
# Generation 153: Best Fitness = 34.0
# Generation 154: Best Fitness = 34.0
# Generation 155: Best Fitness = 34.0
# Generation 156: Best Fitness = 34.0
# Generation 157: Best Fitness = 34.0
# Generation 158: Best Fitness = 34.0
# Generation 159: Best Fitness = 34.0
# Generation 160: Best Fitness = 34.0
# Generation 161: Best Fitness = 34.0
# Generation 162: Best Fitness = 34.0
# Generation 163: Best Fitness = 34.0
# Generation 164: Best Fitness = 34.0
# Generation 165: Best Fitness = 34.0
# Generation 166: Best Fitness = 34.0
# Generation 167: Best Fitness = 34.0
# Generation 168: Best Fitness = 34.0
# Generation 169: Best Fitness = 34.0
# Generation 170: Best Fitness = 34.0
# Generation 171: Best Fitness = 34.0
# Generation 172: Best Fitness = 34.0
# Generation 173: Best Fitness = 34.0
# Generation 174: Best Fitness = 34.0
# Generation 175: Best Fitness = 34.0
# Generation 176: Best Fitness = 34.0
# Generation 177: Best Fitness = 34.0
# Generation 178: Best Fitness = 34.0
# Generation 179: Best Fitness = 34.0
# Generation 180: Best Fitness = 34.0
# Generation 181: Best Fitness = 34.0
# Generation 182: Best Fitness = 34.0
# Generation 183: Best Fitness = 34.0
# Generation 184: Best Fitness = 34.0
# Generation 185: Best Fitness = 34.0
# Generation 186: Best Fitness = 34.0
# Generation 187: Best Fitness = 34.0
# Generation 188: Best Fitness = 34.0
# Generation 189: Best Fitness = 34.0
# Generation 190: Best Fitness = 34.0
# Generation 191: Best Fitness = 34.0
# Generation 192: Best Fitness = 34.0
# Generation 193: Best Fitness = 34.0
# Generation 194: Best Fitness = 34.0
# Generation 195: Best Fitness = 34.0
# Generation 196: Best Fitness = 34.0
# Generation 197: Best Fitness = 34.0
# Generation 198: Best Fitness = 34.0
# Generation 199: Best Fitness = 34.0
# Best Route: [2, 1, 3, 0]
# Best Distance: 34.0
